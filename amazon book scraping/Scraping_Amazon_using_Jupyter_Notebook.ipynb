# %%
try:
    import scrapy
except:
    # !pip install scrapy
    import scrapy
from scrapy.crawler import CrawlerProcess
# Out:
# ...
#      |████████████████████████████████| 235kB 4.7MB/s
# ...
#      |████████████████████████████████| 61kB 22.4MB/s
# ...
#      |████████████████████████████████| 3.1MB 31.5MB/s
# ...
#      |████████████████████████████████| 2.3MB 32.4MB/s
# ...
#      |████████████████████████████████| 61kB 26.3MB/s
# ...
#      |████████████████████████████████| 174kB 41.8MB/s
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-cp36-none-any.whl size=11516 sha256=79b8bbb7b12406eb846d394f9db43b971b07d34ea7deb9e077e09c5bf7961ce2
#   Stored in directory: /root/.cache/pip/wheels/88/99/96/cfef6665f9cb1522ee6757ae5955feedf2fe25f1737f91fa7f
# Successfully built PyDispatcher
# ...

# %% [markdown]
# frist install scrapy and import it
#
# Using following command to create new scrapy project

# %%
# !scrapy startproject amazon_scraping
# Out:
# New Scrapy project 'amazon_scraping', using template directory '/usr/local/lib/python3.6/dist-packages/scrapy/templates/project', created in:
#     /content/amazon_scraping
#
# You can start your first spider with:
#     cd amazon_scraping
#     scrapy genspider example example.com

# %% [markdown]
# Move to scrapy directory

# %%
# %cd amazon_scraping/

# %% [markdown]
# create spider

# %%
# !scrapy genspider amazon_spider amazon.com
# Out:
# Created spider 'amazon_spider' using template 'basic'

# %%
# !pwd
# Out:
# /content

# %%
# %cd amazon_scraping/
# Out:
# /content/amazon_scraping

# %%
# !pwd
# Out:
# /content/amazon_scraping

# %% [markdown]
# install scrapy user agents
#
# do changes in amazon.spider.py (spyder file) file, items.py (items we going to scrap) and setting.py  file

# %%
# !pip install scrapy-user-agents
# Out:
# ...
#   Created wheel for user-agents: filename=user_agents-2.0-cp36-none-any.whl size=10237 sha256=9a623823086c4ba19136d2b92f14b76173dbaec67c820c26ccef5c0433bf251a
#   Stored in directory: /root/.cache/pip/wheels/48/41/70/1ba4d8c9bbca8a54fac6827bc7c48c93d5b44d94829facecba
# Successfully built user-agents
# ...

# %% [markdown]
# run our program

# %%
# !scrapy crawl amazon_spider
# Out:
# 2019-10-23 08:01:18 [scrapy.utils.log] INFO: Scrapy 1.7.4 started (bot: amazon_scraping)
# 2019-10-23 08:01:18 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.7.0, Python 3.6.8 (default, Oct  7 2019, 12:59:55) - [GCC 8.3.0], pyOpenSSL 19.0.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.14.137+-x86_64-with-Ubuntu-18.04-bionic
# 2019-10-23 08:01:18 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'amazon_scraping', 'NEWSPIDER_MODULE': 'amazon_scraping.spiders', 'ROBOTSTXT_OBEY': True, 'SPIDER_MODULES': ['amazon_scraping.spiders'], 'USER_AGENT': 'Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)'}
# 2019-10-23 08:01:18 [scrapy.extensions.telnet] INFO: Telnet Password: afcece28f7036191
# 2019-10-23 08:01:18 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
# ...

# %%
# !pwd
# Out:
# /content/amazon_scraping

# %%
# !zip -r /content/amazon_scraping/file.zip /content/amazon_scraping
# Out:
#   adding: content/amazon_scraping/ (stored 0%)
#   adding: content/amazon_scraping/amazon_scraping/ (stored 0%)
#   adding: content/amazon_scraping/amazon_scraping/pipelines.py (deflated 29%)
#   adding: content/amazon_scraping/amazon_scraping/__pycache__/ (stored 0%)
#   adding: content/amazon_scraping/amazon_scraping/__pycache__/settings.cpython-36.pyc (deflated 29%)
#   adding: content/amazon_scraping/amazon_scraping/__pycache__/items.cpython-36.pyc (deflated 36%)
#   adding: content/amazon_scraping/amazon_scraping/__pycache__/__init__.cpython-36.pyc (deflated 31%)
#   adding: content/amazon_scraping/amazon_scraping/settings.py (deflated 61%)
#   adding: content/amazon_scraping/amazon_scraping/spiders/ (stored 0%)
#   adding: content/amazon_scraping/amazon_scraping/spiders/__pycache__/ (stored 0%)
#   adding: content/amazon_scraping/amazon_scraping/spiders/__pycache__/amazon_spider.cpython-36.pyc (deflated 42%)
# ...

# %%
from google.colab import files
files.download("/content/amazon_scraping/file.zip")
